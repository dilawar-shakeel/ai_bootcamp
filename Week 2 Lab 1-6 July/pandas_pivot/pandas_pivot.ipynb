# %% [markdown]
# <h1 style="color:blue">Pivot basics</h1>

# %%
# # prompt: open shared with me drive

# from google.colab import drive
# drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("weather.csv")
df
# Out:
#        date      city  temperature  humidity
# 0  5/1/2024  new york           65        56
# 1  5/2/2024  new york           66        58
# 2  5/3/2024  new york           68        60
# 3  5/1/2024     dubai           75        80
# 4  5/2/2024     dubai           78        83
# 5  5/3/2024     dubai           82        85
# 6  5/1/2024   beijing           80        26
# 7  5/2/2024   beijing           77        30
# 8  5/3/2024   beijing           79        35

# %%
df.pivot(index='city',columns='date')
# Out:
#          temperature                   humidity
# date        5/1/2024 5/2/2024 5/3/2024 5/1/2024 5/2/2024 5/3/2024
# city
# beijing           80       77       79       26       30       35
# dubai             75       78       82       80       83       85
# new york          65       66       68       56       58       60

# %%
df.pivot(index='city',columns='date',values="humidity")
# Out:
# date      5/1/2024  5/2/2024  5/3/2024
# city
# beijing         26        30        35
# dubai           80        83        85
# new york        56        58        60

# %%
df.pivot(index='date',columns='city')
# Out:
#          temperature                humidity
# city         beijing dubai new york  beijing dubai new york
# date
# 5/1/2024          80    75       65       26    80       56
# 5/2/2024          77    78       66       30    83       58
# 5/3/2024          79    82       68       35    85       60

# %%
df.pivot(index='humidity',columns='city')
# Out:
#               date                     temperature
# city       beijing     dubai  new york     beijing dubai new york
# humidity
# 26        5/1/2024       NaN       NaN        80.0   NaN      NaN
# 30        5/2/2024       NaN       NaN        77.0   NaN      NaN
# 35        5/3/2024       NaN       NaN        79.0   NaN      NaN
# 56             NaN       NaN  5/1/2024         NaN   NaN     65.0
# 58             NaN       NaN  5/2/2024         NaN   NaN     66.0
# 60             NaN       NaN  5/3/2024         NaN   NaN     68.0
# 80             NaN  5/1/2024       NaN         NaN  75.0      NaN
# 83             NaN  5/2/2024       NaN         NaN  78.0      NaN
# 85             NaN  5/3/2024       NaN         NaN  82.0      NaN

# %% [markdown]
# <h1 style="color:blue">Pivot Table</h1>

# %%
# df = pd.read_csv("/content/drive/MyDrive/weather2.csv")
# df

# %%
df.pivot_table(index="city",columns="date")
# Out:
#          humidity                   temperature
# date     5/1/2024 5/2/2024 5/3/2024    5/1/2024 5/2/2024 5/3/2024
# city
# beijing      26.0     30.0     35.0        80.0     77.0     79.0
# dubai        80.0     83.0     85.0        75.0     78.0     82.0
# new york     56.0     58.0     60.0        65.0     66.0     68.0

# %% [markdown]
# <h2 style="color:brown">Margins</h2>

# %%
df.pivot_table(index="city",columns="date",margins=True,aggfunc=np.sum)
# Out:
#          humidity                        temperature
# date     5/1/2024 5/2/2024 5/3/2024  All    5/1/2024 5/2/2024 5/3/2024  All
# city
# beijing        26       30       35   91          80       77       79  236
# dubai          80       83       85  248          75       78       82  235
# new york       56       58       60  174          65       66       68  199
# All           162      171      180  513         220      221      229  670

# %% [markdown]
# <h2 style="color:brown">Grouper</h2>

# %%
# df = pd.read_csv("/content/drive/MyDrive/weather3.csv")
# # df

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.pivot_table(index=pd.Grouper(freq='ME',key='date'),columns='city')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df.pivot_table(index=pd.Grouper(freq='ME',key='date'),columns='city')
#
# File ~\miniconda3\Lib\site-packages\pandas\core\frame.py:11159, in DataFrame.pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort, **kwargs)
#   11155         **kwargs,
#   11156     ) -> DataFrame:
#   11157         from pandas.core.reshape.pivot import pivot_table
#   11158
# > 11159         return pivot_table(
#   11160             self,
#   11161             values=values,
#   11162             index=index,
#
# File ~\miniconda3\Lib\site-packages\pandas\core\reshape\pivot.py:267, in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort, **kwargs)
#     264     table = concat(pieces, keys=keys, axis=1)
#     265     return table.__finalize__(data, method="pivot_table")
# --> 267 table = __internal_pivot_table(
#     268     data,
#     269     values,
#     270     index,
#     271     columns,
#     272     aggfunc,
#     273     fill_value,
#     274     margins,
#     275     dropna,
#     276     margins_name,
#     277     observed,
#     278     sort,
#     279     kwargs,
#     280 )
#     281 return table.__finalize__(data, method="pivot_table")
#
# File ~\miniconda3\Lib\site-packages\pandas\core\reshape\pivot.py:338, in __internal_pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort, kwargs)
#     335             pass
#     336     values = list(values)
# --> 338 grouped = data.groupby(keys, observed=observed, sort=sort, dropna=dropna)
#     339 if values_passed:
#     340     # GH#57876 and GH#61292
#     341     # mypy is not aware `grouped[values]` will always be a DataFrameGroupBy
#     342     grouped = grouped[values]  # type: ignore[assignment]
#
# File ~\miniconda3\Lib\site-packages\pandas\util\_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File ~\miniconda3\Lib\site-packages\pandas\core\frame.py:10833, in DataFrame.groupby(self, by, level, as_index, sort, group_keys, observed, dropna)
#   10829
#   10830         if level is None and by is None:
#   10831             raise TypeError("You have to supply one of 'by' and 'level'")
#   10832
# > 10833         return DataFrameGroupBy(
#   10834             obj=self,
#   10835             keys=by,
#   10836             level=level,
#
# File ~\miniconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1095, in GroupBy.__init__(self, obj, keys, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1092 self.dropna = dropna
#    1094 if grouper is None:
# -> 1095     grouper, exclusions, obj = get_grouper(
#    1096         obj,
#    1097         keys,
#    1098         level=level,
#    1099         sort=sort,
#    1100         observed=observed,
#    1101         dropna=self.dropna,
#    1102     )
#    1104 self.observed = observed
#    1105 self.obj = obj
#
# File ~\miniconda3\Lib\site-packages\pandas\core\groupby\grouper.py:912, in get_grouper(obj, key, level, sort, observed, validate, dropna)
#     907         in_axis = False
#     909     # create the Grouping
#     910     # allow us to passing the actual Grouping as the gpr
#     911     ping = (
# --> 912         Grouping(
#     913             group_axis,
#     914             gpr,
#     915             obj=obj,
#     916             level=level,
#     917             sort=sort,
#     918             observed=observed,
#     919             in_axis=in_axis,
#     920             dropna=dropna,
#     921         )
#     922         if not isinstance(gpr, Grouping)
#     923         else gpr
#     924     )
#     926     groupings.append(ping)
#     928 if len(groupings) == 0 and len(obj):
#
# File ~\miniconda3\Lib\site-packages\pandas\core\groupby\grouper.py:503, in Grouping.__init__(self, index, grouper, obj, level, sort, observed, in_axis, dropna, uniques)
#     497 elif isinstance(grouping_vector, Grouper):
#     498     # get the new grouper; we already have disambiguated
#     499     # what key/level refer to exactly, don't need to
#     500     # check again as we have by this point converted these
#     501     # to an actual value (rather than a pd.Grouper)
#     502     assert self.obj is not None  # for mypy
# --> 503     newgrouper, newobj = grouping_vector._get_grouper(self.obj, validate=False)
#     504     self.obj = newobj
#     506     if isinstance(newgrouper, ops.BinGrouper):
#     507         # TODO: can we unwrap this and get a tighter typing
#     508         #  for self.grouping_vector?
#
# File ~\miniconda3\Lib\site-packages\pandas\core\resample.py:2565, in TimeGrouper._get_grouper(self, obj, validate, observed)
#    2550 """
#    2551 Parameters
#    2552 ----------
#    (...)   2562 A tuple of grouper, obj (possibly sorted)
#    2563 """
#    2564 # create the resampler and return our binner
# -> 2565 r = self._get_resampler(obj)
#    2566 return r._grouper, cast(NDFrameT, r.obj)
#
# File ~\miniconda3\Lib\site-packages\pandas\core\resample.py:2541, in TimeGrouper._get_resampler(self, obj)
#    2533 elif isinstance(ax, TimedeltaIndex):
#    2534     return TimedeltaIndexResampler(
#    2535         obj,
#    2536         timegrouper=self,
#    2537         group_keys=self.group_keys,
#    2538         gpr_index=ax,
#    2539     )
# -> 2541 raise TypeError(
#    2542     "Only valid with DatetimeIndex, "
#    2543     "TimedeltaIndex or PeriodIndex, "
#    2544     f"but got an instance of '{type(ax).__name__}'"
#    2545 )
#
# TypeError: Only valid with DatetimeIndex, TimedeltaIndex or PeriodIndex, but got an instance of 'Index'
