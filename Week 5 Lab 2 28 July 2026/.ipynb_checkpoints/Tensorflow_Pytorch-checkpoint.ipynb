# %% [markdown]
# #Introduction to TensorFlow

# %% [markdown]
# # 📘 TensorFlow Basics
#
# TensorFlow is a powerful open-source library developed by Google for deep learning and numerical computation. It uses dataflow graphs and automatic differentiation to perform optimized computations.
#
# Let's get started by learning how to use Tensors, which are the fundamental building blocks of TensorFlow.

# %% [markdown]
# ##Installing and Importing TensorFlow

# %%
# !pip install tensorflow
import tensorflow as tf
print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.21.0

# %% [markdown]
# ## 📦 Tensors
#
# Tensors are multi-dimensional arrays (like NumPy arrays). TensorFlow supports scalar (0D), vector (1D), matrix (2D), and higher dimensional tensors.
#
# Let's see how to create and inspect them.

# %% [markdown]
# ##Tensor Creation and Attributes

# %%
# Scalar
scalar = tf.constant(7)
print("Scalar:", scalar)

# Vector
vector = tf.constant([1.0, 2.0, 3.0])
print("Vector:", vector)

# Matrix
matrix = tf.constant([[1, 2], [3, 4]])
print("Matrix:\n", matrix)

# Check shape and dtype
print("Shape:", matrix.shape)
print("Data Type:", matrix.dtype)
# Out:
# Scalar: tf.Tensor(7, shape=(), dtype=int32)
# Vector: tf.Tensor([1. 2. 3.], shape=(3,), dtype=float32)
# Matrix:
#  tf.Tensor(
# [[1 2]
#  [3 4]], shape=(2, 2), dtype=int32)
# Shape: (2, 2)
# Data Type: <dtype: 'int32'>

# %% [markdown]
# ## ➕ Tensor Operations
#
# TensorFlow supports element-wise operations like addition, multiplication, matrix multiplication, etc.

# %% [markdown]
# ##Tensor Arithmetic

# %%
a = tf.constant([[1, 2], [3, 4]])
b = tf.constant([[5, 6], [7, 8]])

# Addition
print("Addition:\n", tf.add(a, b))

# Multiplication (element-wise)
print("Element-wise Multiplication:\n", tf.multiply(a, b))

# Matrix multiplication
print("Matrix Multiplication:\n", tf.matmul(a, b))
# Out:
# Addition:
#  tf.Tensor(
# [[ 6  8]
#  [10 12]], shape=(2, 2), dtype=int32)
# Element-wise Multiplication:
#  tf.Tensor(
# [[ 5 12]
#  [21 32]], shape=(2, 2), dtype=int32)
# Matrix Multiplication:
#  tf.Tensor(
# [[19 22]
#  [43 50]], shape=(2, 2), dtype=int32)

# %% [markdown]
# # 🏗️ Building a Neural Network with TensorFlow (Keras)
#
# We'll use `tf.keras`, a high-level API for building and training models. Let's train a simple neural network to classify digits using the MNIST dataset.

# %% [markdown]
# ##Load Dataset and Normalize

# %%
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize to [0, 1]
x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
print(x_train.shape)
# Out:
# (60000, 28, 28)

# %% [markdown]
# ##Define a Model

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(28, 28)),
    tf.keras.layers.Flatten(),  # Input layer
    tf.keras.layers.Dense(128, activation='relu'),  # Hidden layer
    tf.keras.layers.Dense(10, activation='softmax') # Output layer
])

# %% [markdown]
# ##Compile and Train

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
model.fit(x_train, y_train, epochs=5)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 18s 8ms/step - accuracy: 0.9248 - loss: 0.2619
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 15s 8ms/step - accuracy: 0.9665 - loss: 0.1137
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 15s 8ms/step - accuracy: 0.9762 - loss: 0.0776
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - accuracy: 0.9826 - loss: 0.0581
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 15s 8ms/step - accuracy: 0.9858 - loss: 0.0459

# %% [markdown]
# ##Evaluate the Model

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
print("\nTest Accuracy:", test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9757 - loss: 0.0753
#
# Test Accuracy: 0.9757000207901001

# %% [markdown]
# #1. Understand the Basic Syntax and Operations (PyTorch)

# %% [markdown]
# # Introduction to PyTorch
# ## 🔥 PyTorch Basics
#
# PyTorch is a popular open-source deep learning library developed by Facebook AI. It provides flexibility and speed through dynamic computation graphs and strong GPU support.
#
# In this section, we'll start by exploring how PyTorch handles tensors and automatic differentiation.

# %% [markdown]
# ##Installing and Importing PyTorch

# %%
# If you're in a notebook or Colab
# !pip install torch
import torch
print("PyTorch version:", torch.__version__)
# Out:
# PyTorch version: 2.13.0+cpu

# %% [markdown]
# ##Creating and Inspecting Tensors
# ## 📦 Tensors in PyTorch
#
# Tensors are multidimensional arrays, just like in NumPy. They're the building blocks of PyTorch and support operations like addition, multiplication, reshaping, etc.

# %% [markdown]
# ##Tensor Creation and Properties

# %%
# Scalar
scalar = torch.tensor(5)
print("Scalar:", scalar)

# Vector
vector = torch.tensor([1.0, 2.0, 3.0])
print("Vector:", vector)

# Matrix
matrix = torch.tensor([[1.0, 2.0], [3.0, 4.0]])
print("Matrix:\n", matrix)

# Shape and data type
print("Shape:", matrix.shape)
print("Data Type:", matrix.dtype)
# Out:
# Scalar: tensor(5)
# Vector: tensor([1., 2., 3.])
# Matrix:
#  tensor([[1., 2.],
#         [3., 4.]])
# Shape: torch.Size([2, 2])
# Data Type: torch.float32

# %% [markdown]
# ## ➕ Tensor Operations
#
# PyTorch supports common element-wise operations as well as matrix multiplication, reshaping, and broadcasting.

# %% [markdown]
# ##Tensor Arithmetic

# %%
a = torch.tensor([[1, 2], [3, 4]], dtype=torch.float32)
b = torch.tensor([[5, 6], [7, 8]], dtype=torch.float32)

# Addition
print("Addition:\n", a + b)

# Element-wise multiplication
print("Element-wise Multiplication:\n", a * b)

# Matrix multiplication
print("Matrix Multiplication:\n", torch.matmul(a, b))
# Out:
# Addition:
#  tensor([[ 6.,  8.],
#         [10., 12.]])
# Element-wise Multiplication:
#  tensor([[ 5., 12.],
#         [21., 32.]])
# Matrix Multiplication:
#  tensor([[19., 22.],
#         [43., 50.]])

# %%
# !pip install torch torchvision

# %% [markdown]
# # 🏗️ Building a Neural Network with PyTorch
#
# Now let's build a simple neural network to classify digits from the MNIST dataset using `torch.nn` and `torch.optim`.

# %% [markdown]
# ##Load and Normalize MNIST Dataset

# %%
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

# Transform: Normalize to [0, 1]
transform = transforms.ToTensor()

train_data = datasets.MNIST(root='data', train=True, download=True, transform=transform)
test_data = datasets.MNIST(root='data', train=False, download=True, transform=transform)

train_loader = DataLoader(train_data, batch_size=64, shuffle=True)
test_loader = DataLoader(test_data, batch_size=64, shuffle=False)

# %% [markdown]
# ##Define Neural Network

# %%
import torch.nn as nn
import torch.nn.functional as F

class SimpleNN(nn.Module):
    def __init__(self):
        super(SimpleNN, self).__init__()
        self.fc1 = nn.Linear(28 * 28, 128)
        self.fc2 = nn.Linear(128, 10)

    def forward(self, x):
        x = x.view(x.shape[0], -1)  # Flatten
        x = F.relu(self.fc1(x))
        return F.log_softmax(self.fc2(x), dim=1)

model = SimpleNN()

# %% [markdown]
# ##Define Loss and Optimizer

# %%
import torch.optim as optim

criterion = nn.NLLLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %% [markdown]
# ##Train the Model

# %%
epochs = 3
for epoch in range(epochs):
    for images, labels in train_loader:
        optimizer.zero_grad()
        output = model(images)
        loss = criterion(output, labels)
        loss.backward()
        optimizer.step()
    print(f"Epoch {epoch+1}, Loss: {loss.item():.4f}")
# Out:
# Epoch 1, Loss: 0.2700
# Epoch 2, Loss: 0.0356
# Epoch 3, Loss: 0.0329

# %% [markdown]
# ##Evaluate Accuracy

# %%
correct = 0
total = 0
with torch.no_grad():
    for images, labels in test_loader:
        outputs = model(images)
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f"Test Accuracy: {correct / total * 100:.2f}%")

# %% [markdown]
# #3. Compare Similarities and Differences with TensorFlow
#
#
# # PyTorch vs TensorFlow: Quick Comparison
#
# | Feature                | PyTorch                               | TensorFlow                           |
# |------------------------|----------------------------------------|--------------------------------------|
# | Execution Mode         | Eager (Dynamic)                        | Eager (Static with option for Graph) |
# | High-Level API         | `torch.nn`, `torch.optim`              | `tf.keras`                           |
# | Dataset Loader         | `DataLoader`                           | `tf.data.Dataset`                    |
# | Training Loop Style    | Mostly manual                          | `model.fit()` or manual              |
# | Model Saving           | `torch.save()`                         | `model.save()` or `SavedModel`       |
# | Visualization Tool     | TensorBoard (via `torch.utils.tensorboard`) | TensorBoard                    |
# | Autograd Support       | Built-in via `autograd`                | `tf.GradientTape()`                  |
#
# Both libraries are capable of building state-of-the-art models. Your choice depends on project needs and comfort with syntax.

# %% [markdown]
# --------------------------------------------------------------------------------

# %% [markdown]
# #Activity
#
# Create two custom models, one with Tensorflow and the other with Pytorch.
# The models should have
#
# ###  Model Architecture (Same for Both Frameworks)
#
# | Layer Type         | Configuration                      |
# |--------------------|-------------------------------------|
# | Input Layer        | Flatten (28×28 → 784)              |
# | Dense Layer 1      | 256 units, ReLU                    |
# | Dropout Layer      | 30% (rate = 0.3)                   |
# | Dense Layer 2      | 128 units, Tanh                    |
# | Output Layer       | 10 units, Softmax (TF) / LogSoftmax (PT) |
#
# ###  Instructions
#
# - Implement this architecture using `tf.keras.Sequential` in TensorFlow.
# - Implement the same architecture using `torch.nn.Module` in PyTorch.
# - Train both models for **5 epochs** using the **Adam optimizer** and an appropriate classification loss.
# - Evaluate accuracy on the MNIST test set.

# %%
import tensorflow as tf

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(28,28)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(256,activation="relu"),
    tf.keras.layers.Dropout(rate=0.3),
    tf.keras.layers.Dense(10, activation="softmax")
])

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=[tf.keras.metrics.SparseCategoricalAccuracy()]
)

model.fit(x_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - loss: 0.0608 - sparse_categorical_accuracy: 0.9804
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 18s 9ms/step - loss: 0.0518 - sparse_categorical_accuracy: 0.9834
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 17s 9ms/step - loss: 0.0463 - sparse_categorical_accuracy: 0.9850
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 17s 9ms/step - loss: 0.0428 - sparse_categorical_accuracy: 0.9860
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 17s 9ms/step - loss: 0.0402 - sparse_categorical_accuracy: 0.9867

# %%
loss,acc = model.evaluate(x_test, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0661 - sparse_categorical_accuracy: 0.9814

# %%
import torch

# %%
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

# Transform: Normalize to [0, 1]
transform = transforms.ToTensor()

train_data = datasets.MNIST(root='data', train=True, download=True, transform=transform)
test_data = datasets.MNIST(root='data', train=False, download=True, transform=transform)

train_loader = DataLoader(train_data, batch_size=64, shuffle=True)
test_loader = DataLoader(test_data, batch_size=64, shuffle=False)

# %%
from torch import nn
import torch.nn.functional as F 

class SimpleNN(nn.Module):
    def __init__(self):
        super(SimpleNN, self).__init__()
        self.fc1 = nn.Linear(28*28,256)
        self.fc2 = nn.Dropout(p=0.3)
        self.fc3 = nn.Linear(256,10)

    def forward(self, x):
        x = x.view(x.shape[0],-1)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return F.log_softmax(self.fc3(x), dim=1)


my_network=SimpleNN()

# %%
import torch.optim as optim

criterion = nn.NLLLoss()
optimizer = optim.Adam(my_network.parameters(), lr=0.001)

# %%
epochs=5
for epoch in range(epochs):
    for image, labels in train_loader:
        optimizer.zero_grad()
        output =  my_network(image)
        loss = criterion(output, labels)
        loss.backward()
        optimizer.step()
    print(f"Epoch {epoch+1}, Loss: {loss.item():.4f}")
# Out:
# Epoch 1, Loss: 0.1483
# Epoch 2, Loss: 0.1537
# Epoch 3, Loss: 0.0315
# Epoch 4, Loss: 0.1867
# Epoch 5, Loss: 0.0217

# %%
my_network.eval() 

correct = 0
total = 0

with torch.no_grad():
    for image, labels in test_loader:
        outputs = my_network(image)
        
        _, predicted = torch.max(outputs, 1)
        
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

# Calculate and display the final accuracy percentage
accuracy = (correct / total) * 100
print(f"Test Accuracy: {accuracy:.2f}%")
# Out:
# Test Accuracy: 97.76%

# %% [markdown]
# # EXTRA

# %%
import tensorflow as tf

mnist = tf.keras.datasets.fashion_mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize to [0, 1]
x_train, x_test = x_train / 255.0, x_test / 255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 2us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 6s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 2us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(28,28)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(256,activation="relu"),
    tf.keras.layers.Dropout(rate=0.3),
    tf.keras.layers.Dense(10, activation="softmax")
])


model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
model.fit(x_train, y_train, epochs=epochs*2, batch_size=64)
# Out:
# Epoch 1/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.8808 - loss: 0.3209
# Epoch 2/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.8852 - loss: 0.3089
# Epoch 3/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.8893 - loss: 0.3014
# Epoch 4/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.8914 - loss: 0.2933
# Epoch 5/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.8930 - loss: 0.2859
# Epoch 6/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.8952 - loss: 0.2793
# Epoch 7/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.8978 - loss: 0.2731
# Epoch 8/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.8993 - loss: 0.2663
# Epoch 9/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.9028 - loss: 0.2603
# Epoch 10/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9038 - loss: 0.2561

# %%
test_loss, test_acc = model.evaluate(x_test,  y_test, verbose=2)

print(f"\nFinal Test Accuracy: {test_acc*100:.2f}%")
# Out:
# 313/313 - 2s - 6ms/step - accuracy: 0.8834 - loss: 0.3349
#
# Final Test Accuracy: 88.34%

# %%
model.fit(x_train, y_train, epochs=epochs*2, batch_size=128)
# Out:
# Epoch 1/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9137 - loss: 0.2294
# Epoch 2/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9153 - loss: 0.2255
# Epoch 3/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9160 - loss: 0.2222
# Epoch 4/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9167 - loss: 0.2202
# Epoch 5/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9157 - loss: 0.2206
# Epoch 6/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9179 - loss: 0.2162
# Epoch 7/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9185 - loss: 0.2119
# Epoch 8/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9202 - loss: 0.2124
# Epoch 9/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9223 - loss: 0.2079
# Epoch 10/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9218 - loss: 0.2069

# %%
test_loss, test_acc = model.evaluate(x_test,  y_test, verbose=2)

print(f"\nFinal Test Accuracy: {test_acc*100:.2f}%")
# Out:
# 313/313 - 2s - 5ms/step - accuracy: 0.8949 - loss: 0.3145
#
# Final Test Accuracy: 89.49%

# %%
model.fit(x_train, y_train, epochs=epochs*2, batch_size=16)
# Out:
# Epoch 1/10
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 29s 8ms/step - accuracy: 0.8846 - loss: 0.3108
# Epoch 2/10
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 29s 8ms/step - accuracy: 0.8947 - loss: 0.2834
# Epoch 3/10
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 30s 8ms/step - accuracy: 0.8965 - loss: 0.2767
# Epoch 4/10
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 29s 8ms/step - accuracy: 0.9004 - loss: 0.2710
# Epoch 5/10
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 29s 8ms/step - accuracy: 0.9012 - loss: 0.2648
# Epoch 6/10
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 29s 8ms/step - accuracy: 0.9007 - loss: 0.2624
# Epoch 7/10
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 30s 8ms/step - accuracy: 0.9027 - loss: 0.2588
# Epoch 8/10
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 31s 8ms/step - accuracy: 0.9035 - loss: 0.2568
# Epoch 9/10
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 29s 8ms/step - accuracy: 0.9045 - loss: 0.2519
# Epoch 10/10
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 30s 8ms/step - accuracy: 0.9077 - loss: 0.2443

# %%
test_loss, test_acc = model.evaluate(x_test,  y_test, verbose=2)

print(f"\nFinal Test Accuracy: {test_acc*100:.2f}%")
# Out:
# 313/313 - 2s - 6ms/step - accuracy: 0.8811 - loss: 0.3855
#
# Final Test Accuracy: 88.11%
